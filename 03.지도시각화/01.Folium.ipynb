# %% [markdown]
# # 포리움 지도 시각화

# %%
import folium
folium.__version__
# Out:
# '0.12.1.post1'

# %%
map=folium.Map(location=[35.159841,126.851784],zoom_start=12)
folium.Marker(
    location=[35.159841,126.851784],
    popup=folium.Popup('광주광역시 서구 내방로 111',max_width=200),
    tooltip='광주광역시청'
).add_to(map)
folium.Marker(
    location=[35.146107, 126.92331],
    popup=folium.Popup('광주광역시 동구 서남로 1',max_width=200),
    tooltip='광주광역시 동구청'
).add_to(map)
folium.Marker(
    location=[35.15208, 126.88985],
    popup=folium.Popup('광주광역시 서구 농성동 경열로 33',max_width=200),
    tooltip='광주광역시 서구청'
).add_to(map)
folium.Marker(
    location=[35.1741004, 126.9121570],
    popup=folium.Popup('광주광역시 북구 우치로 77',max_width=200),
    tooltip='광주광역시 북구청'
).add_to(map)
folium.Marker(
    location=[35.1329009, 126.9025733],
    popup=folium.Popup('광주광역시 남구 봉선로 1',max_width=200),
    tooltip='광주광역시 남구청'
).add_to(map)
folium.Marker(
    location=[35.1395519, 126.7938068],
    popup=folium.Popup('광주광역시 광산구 광산로29번길 15',max_width=200),
    tooltip='광주광역시 광산구청'
).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5802f068c17c88d4852fadf2b2c2eedd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5802f068c17c88d4852fadf2b2c2eedd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5802f068c17c88d4852fadf2b2c2eedd = L.map(
#                 &quot;map_5802f068c17c88d4852fadf2b2c2eedd&quot;,
#                 {
#                     center: [35.159841, 126.851784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_296f797cbe81d5f48e846ca47f6b66ac = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5802f068c17c88d4852fadf2b2c2eedd);
#
#
#             var marker_696d03e0cfd35fabfa2cc9c762eecdbb = L.marker(
#                 [35.159841, 126.851784],
#                 {}
#             ).addTo(map_5802f068c17c88d4852fadf2b2c2eedd);
#
#
#         var popup_4badd3d2a0108803bb7c74e92969eeb8 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_7c4f194a78e604a5958c7831003959e4 = $(`&lt;div id=&quot;html_7c4f194a78e604a5958c7831003959e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 서구 내방로 111&lt;/div&gt;`)[0];
#             popup_4badd3d2a0108803bb7c74e92969eeb8.setContent(html_7c4f194a78e604a5958c7831003959e4);
#
#
#         marker_696d03e0cfd35fabfa2cc9c762eecdbb.bindPopup(popup_4badd3d2a0108803bb7c74e92969eeb8)
#         ;
#
#
#
#
#             marker_696d03e0cfd35fabfa2cc9c762eecdbb.bindTooltip(
#                 `&lt;div&gt;
#                      광주광역시청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2d0ba5a5d584e8bc1e0517b78cdf1728 = L.marker(
#                 [35.146107, 126.92331],
#                 {}
#             ).addTo(map_5802f068c17c88d4852fadf2b2c2eedd);
#
#
#         var popup_8dcb9c089e517f448c2f16479176e529 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_400808ee93ff82dc3998466cf4b537af = $(`&lt;div id=&quot;html_400808ee93ff82dc3998466cf4b537af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 동구 서남로 1&lt;/div&gt;`)[0];
#             popup_8dcb9c089e517f448c2f16479176e529.setContent(html_400808ee93ff82dc3998466cf4b537af);
#
#
#         marker_2d0ba5a5d584e8bc1e0517b78cdf1728.bindPopup(popup_8dcb9c089e517f448c2f16479176e529)
#         ;
#
#
#
#
#             marker_2d0ba5a5d584e8bc1e0517b78cdf1728.bindTooltip(
#                 `&lt;div&gt;
#                      광주광역시 동구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9b018d05b288fcde8da7ef28b613221e = L.marker(
#                 [35.15208, 126.88985],
#                 {}
#             ).addTo(map_5802f068c17c88d4852fadf2b2c2eedd);
#
#
#         var popup_bef01133fbd834eeb0e033ead6cc4bdb = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_57e1f86ab72630c05b0f38199245bc24 = $(`&lt;div id=&quot;html_57e1f86ab72630c05b0f38199245bc24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 서구 농성동 경열로 33&lt;/div&gt;`)[0];
#             popup_bef01133fbd834eeb0e033ead6cc4bdb.setContent(html_57e1f86ab72630c05b0f38199245bc24);
#
#
#         marker_9b018d05b288fcde8da7ef28b613221e.bindPopup(popup_bef01133fbd834eeb0e033ead6cc4bdb)
#         ;
#
#
#
#
#             marker_9b018d05b288fcde8da7ef28b613221e.bindTooltip(
#                 `&lt;div&gt;
#                      광주광역시 서구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4561d08ebfb7b6ef25c52595851d859c = L.marker(
#                 [35.1741004, 126.912157],
#                 {}
#             ).addTo(map_5802f068c17c88d4852fadf2b2c2eedd);
#
#
#         var popup_2e569d1b4c2279b60582070dca9f0ffa = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_d5a16064e91baa5ac19a7640966474bc = $(`&lt;div id=&quot;html_d5a16064e91baa5ac19a7640966474bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 북구 우치로 77&lt;/div&gt;`)[0];
#             popup_2e569d1b4c2279b60582070dca9f0ffa.setContent(html_d5a16064e91baa5ac19a7640966474bc);
#
#
#         marker_4561d08ebfb7b6ef25c52595851d859c.bindPopup(popup_2e569d1b4c2279b60582070dca9f0ffa)
#         ;
#
#
#
#
#             marker_4561d08ebfb7b6ef25c52595851d859c.bindTooltip(
#                 `&lt;div&gt;
#                      광주광역시 북구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b47ac425423e061d479bdaf7c3ca9ea9 = L.marker(
#                 [35.1329009, 126.9025733],
#                 {}
#             ).addTo(map_5802f068c17c88d4852fadf2b2c2eedd);
#
#
#         var popup_749d39a815e52572086308e0002b99fb = L.popup({&quot;maxWidth&quot;: 200});

# %%
map.save('광주시_주요관공서.html')

# %%
 Open street map에 광주광역시청과 구청을 표시
map = folium.Map(location=[35.159841, 126.851784], zoom_start=13)
folium.Marker(
    location=[35.159841, 126.851784],
    popup=folium.Popup('광주광역시 서구 내방로 111', max_width=200),
    tooltip='광주광역시청'
).add_to(map)
folium.Marker(
    location=[35.146107, 126.923315],
    popup=folium.Popup('광주광역시 동구 서남로 1', max_width=200),
    tooltip='광주 동구청'
).add_to(map)
folium.Marker(
    location=[35.152089, 126.889858],
    popup=folium.Popup('광주광역시 서구 농성동 경열로 33', max_width=200),
    tooltip='광주 서구청'
).add_to(map)
folium.Marker(
    location=[35.1741, 126.912157],
    popup=folium.Popup('광주광역시 북구 우치로 77', max_width=200),
    tooltip='광주 북구청'
).add_to(map)
folium.Marker(
    location=[35.132901, 126.902573],
    popup=folium.Popup('광주광역시 남구 봉선로 1', max_width=200),
    tooltip='광주 남구청'
).add_to(map)
folium.Marker(
    location=[35.159552, 126.793807],
    popup=folium.Popup('광주광역시 광산구 광산로29번길 15', max_width=200),
    tooltip='광주 광산구청'
).add_to(map)
map
# Out:
#   Input In [19]
#     Open street map에 광주광역시청과 구청을 표시
#          ^
# SyntaxError: invalid syntax

# %%
map.save('광주시_주요관공서.html')

# %%
# Stamen Toner map에 광주광역시청과 구청을 표시
from folium.features import CustomIcon, DivIcon

map = folium.Map(location=[35.159841, 126.851784], tiles="Stamen Toner", zoom_start=13)
folium.Marker(
    location=[35.159841, 126.851784],
    popup=folium.Popup('광주광역시 서구 내방로 111', max_width=200),
    tooltip='광주광역시청',
).add_to(map)
folium.Marker(
    location=[35.146107, 126.923315],
    popup=folium.Popup('광주광역시 동구 서남로 1', max_width=200),
    tooltip='광주 동구청',
    icon=DivIcon(icon_size=(100,20), icon_anchor=(0,0),
                 html='<div style="font-size: 14pt; background-color: powderblue"><bold>광주 동구청</bold></div>')
).add_to(map)
folium.Circle(
    radius=250,
    location=[35.152089, 126.889858],
    popup=folium.Popup('광주광역시 서구 농성동 경열로 33', max_width=200),
    tooltip='광주 서구청',
    color='magenta',
    fill=True
).add_to(map)
folium.CircleMarker(
    radius=20,
    location=[35.1741, 126.912157],
    popup=folium.Popup('광주광역시 북구 우치로 77', max_width=200),
    tooltip='광주 북구청',
    color="#3186aa",        # RGB, 16진수
    fill=True,
    fill_color="#3186dd"
).add_to(map)
folium.Marker(
    location=[35.132901, 126.902573],
    popup=folium.Popup('광주광역시 남구 봉선로 1', max_width=200),
    tooltip='광주 남구청',
    icon=folium.Icon('darkred', icon='star')
).add_to(map)
folium.Marker(
    location=[35.159552, 126.793807],
    popup=folium.Popup('광주광역시 광산구 광산로29번길 15', max_width=200),
    tooltip='광주 광산구청',
    icon=folium.Icon('blue', icon='plane')
).add_to(map)

title_html = '<h3 align="center">광주광역시 주요 행정기관</h3>'
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4f3cb42bc89c7c86780f224a6372169f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#     &lt;h3 align=&quot;center&quot;&gt;광주광역시 주요 행정기관&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4f3cb42bc89c7c86780f224a6372169f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4f3cb42bc89c7c86780f224a6372169f = L.map(
#                 &quot;map_4f3cb42bc89c7c86780f224a6372169f&quot;,
#                 {
#                     center: [35.159841, 126.851784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_635983bb521b1a602886fcf5bba1e549 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4f3cb42bc89c7c86780f224a6372169f);
#
#
#             var marker_49883ff93018891ac85cd5d457f7740e = L.marker(
#                 [35.159841, 126.851784],
#                 {}
#             ).addTo(map_4f3cb42bc89c7c86780f224a6372169f);
#
#
#         var popup_00e0fa83c83817c20fdefd767a9053c2 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_a2d298217cd4d77da3476170b8c5f07d = $(`&lt;div id=&quot;html_a2d298217cd4d77da3476170b8c5f07d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 서구 내방로 111&lt;/div&gt;`)[0];
#             popup_00e0fa83c83817c20fdefd767a9053c2.setContent(html_a2d298217cd4d77da3476170b8c5f07d);
#
#
#         marker_49883ff93018891ac85cd5d457f7740e.bindPopup(popup_00e0fa83c83817c20fdefd767a9053c2)
#         ;
#
#
#
#
#             marker_49883ff93018891ac85cd5d457f7740e.bindTooltip(
#                 `&lt;div&gt;
#                      광주광역시청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_386a87b6c6629827169c035805b7876a = L.marker(
#                 [35.146107, 126.923315],
#                 {}
#             ).addTo(map_4f3cb42bc89c7c86780f224a6372169f);
#
#
#             var div_icon_ddf9d15a3678c32d72a18fcebdce84a6 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 14pt; background-color: powderblue\&quot;\u003e\u003cbold\u003e\uad11\uc8fc \ub3d9\uad6c\uccad\u003c/bold\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [100, 20]});
#             marker_386a87b6c6629827169c035805b7876a.setIcon(div_icon_ddf9d15a3678c32d72a18fcebdce84a6);
#
#
#         var popup_a0b66e367008f8cc0148bfc7fff4e7ff = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_e74e9687823dc543459714b3f997b2dc = $(`&lt;div id=&quot;html_e74e9687823dc543459714b3f997b2dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 동구 서남로 1&lt;/div&gt;`)[0];
#             popup_a0b66e367008f8cc0148bfc7fff4e7ff.setContent(html_e74e9687823dc543459714b3f997b2dc);
#
#
#         marker_386a87b6c6629827169c035805b7876a.bindPopup(popup_a0b66e367008f8cc0148bfc7fff4e7ff)
#         ;
#
#
#
#
#             marker_386a87b6c6629827169c035805b7876a.bindTooltip(
#                 `&lt;div&gt;
#                      광주 동구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_1d39e9febe9156b3fbaffc374804e18b = L.circle(
#                 [35.152089, 126.889858],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;magenta&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;magenta&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 250, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4f3cb42bc89c7c86780f224a6372169f);
#
#
#         var popup_0e4dc3cfc511cba6345c0f44f559129a = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_00354622cc74d234fef7fa936c9451ad = $(`&lt;div id=&quot;html_00354622cc74d234fef7fa936c9451ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 서구 농성동 경열로 33&lt;/div&gt;`)[0];
#             popup_0e4dc3cfc511cba6345c0f44f559129a.setContent(html_00354622cc74d234fef7fa936c9451ad);
#
#
#         circle_1d39e9febe9156b3fbaffc374804e18b.bindPopup(popup_0e4dc3cfc511cba6345c0f44f559129a)
#         ;
#
#
#
#
#             circle_1d39e9febe9156b3fbaffc374804e18b.bindTooltip(
#                 `&lt;div&gt;
#                      광주 서구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_d87800be5d8d8e0ff051bf2598440dff = L.circ
