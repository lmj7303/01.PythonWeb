# %% [markdown]
# # 포리움 지도 시각화

# %%
import folium
folium.__version__
# Out:
# '0.12.1.post1'

# %%
map=folium.Map(location=[35.159841,126.851784],zoom_start=12)
folium.Marker(
    location=[35.159841,126.851784],
    popup=folium.Popup('광주광역시 서구 내방로 111',max_width=200),
    tooltip='광주광역시청'
).add_to(map)
folium.Marker(
    location=[35.146107, 126.92331],
    popup=folium.Popup('광주광역시 동구 서남로 1',max_width=200),
    tooltip='광주광역시 동구청'
).add_to(map)
folium.Marker(
    location=[35.15208, 126.88985],
    popup=folium.Popup('광주광역시 서구 농성동 경열로 33',max_width=200),
    tooltip='광주광역시 서구청'
).add_to(map)
folium.Marker(
    location=[35.1741004, 126.9121570],
    popup=folium.Popup('광주광역시 북구 우치로 77',max_width=200),
    tooltip='광주광역시 북구청'
).add_to(map)
folium.Marker(
    location=[35.1329009, 126.9025733],
    popup=folium.Popup('광주광역시 남구 봉선로 1',max_width=200),
    tooltip='광주광역시 남구청'
).add_to(map)
folium.Marker(
    location=[35.1395519, 126.7938068],
    popup=folium.Popup('광주광역시 광산구 광산로29번길 15',max_width=200),
    tooltip='광주광역시 광산구청'
).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e1d558d7cb5d17fd3c95a5f4ba5dbb5d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e1d558d7cb5d17fd3c95a5f4ba5dbb5d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e1d558d7cb5d17fd3c95a5f4ba5dbb5d = L.map(
#                 &quot;map_e1d558d7cb5d17fd3c95a5f4ba5dbb5d&quot;,
#                 {
#                     center: [35.159841, 126.851784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_023b16f02f71e93738483b3d8913cafe = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e1d558d7cb5d17fd3c95a5f4ba5dbb5d);
#
#
#             var marker_cbb7669077946b2f483928b2ba0c5156 = L.marker(
#                 [35.159841, 126.851784],
#                 {}
#             ).addTo(map_e1d558d7cb5d17fd3c95a5f4ba5dbb5d);
#
#
#         var popup_2b29aad3c311ea747f4805ac292e5fc5 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_69323bc5fb9f02b5b9cf12dfb79e5502 = $(`&lt;div id=&quot;html_69323bc5fb9f02b5b9cf12dfb79e5502&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 서구 내방로 111&lt;/div&gt;`)[0];
#             popup_2b29aad3c311ea747f4805ac292e5fc5.setContent(html_69323bc5fb9f02b5b9cf12dfb79e5502);
#
#
#         marker_cbb7669077946b2f483928b2ba0c5156.bindPopup(popup_2b29aad3c311ea747f4805ac292e5fc5)
#         ;
#
#
#
#
#             marker_cbb7669077946b2f483928b2ba0c5156.bindTooltip(
#                 `&lt;div&gt;
#                      광주광역시청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f6b60cefc63a68b43b846a26ea286379 = L.marker(
#                 [35.146107, 126.92331],
#                 {}
#             ).addTo(map_e1d558d7cb5d17fd3c95a5f4ba5dbb5d);
#
#
#         var popup_4be936855bda31043a83192bb5299510 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_9281ec881cacc4d4506bd6529875f3a1 = $(`&lt;div id=&quot;html_9281ec881cacc4d4506bd6529875f3a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 동구 서남로 1&lt;/div&gt;`)[0];
#             popup_4be936855bda31043a83192bb5299510.setContent(html_9281ec881cacc4d4506bd6529875f3a1);
#
#
#         marker_f6b60cefc63a68b43b846a26ea286379.bindPopup(popup_4be936855bda31043a83192bb5299510)
#         ;
#
#
#
#
#             marker_f6b60cefc63a68b43b846a26ea286379.bindTooltip(
#                 `&lt;div&gt;
#                      광주광역시 동구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9e3cde154ad25f38b190730355516e5c = L.marker(
#                 [35.15208, 126.88985],
#                 {}
#             ).addTo(map_e1d558d7cb5d17fd3c95a5f4ba5dbb5d);
#
#
#         var popup_93b5935b441d0cec78edcbeb4f042154 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_99af3633eca6d0bf3c1d593290f52a09 = $(`&lt;div id=&quot;html_99af3633eca6d0bf3c1d593290f52a09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 서구 농성동 경열로 33&lt;/div&gt;`)[0];
#             popup_93b5935b441d0cec78edcbeb4f042154.setContent(html_99af3633eca6d0bf3c1d593290f52a09);
#
#
#         marker_9e3cde154ad25f38b190730355516e5c.bindPopup(popup_93b5935b441d0cec78edcbeb4f042154)
#         ;
#
#
#
#
#             marker_9e3cde154ad25f38b190730355516e5c.bindTooltip(
#                 `&lt;div&gt;
#                      광주광역시 서구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_80ccdcbd552ef5c3085b34645477b1aa = L.marker(
#                 [35.1741004, 126.912157],
#                 {}
#             ).addTo(map_e1d558d7cb5d17fd3c95a5f4ba5dbb5d);
#
#
#         var popup_2d97e4b185f373c829f773022e86779a = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_69ff6ab696b0570f10d89e70e5b5fc94 = $(`&lt;div id=&quot;html_69ff6ab696b0570f10d89e70e5b5fc94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 북구 우치로 77&lt;/div&gt;`)[0];
#             popup_2d97e4b185f373c829f773022e86779a.setContent(html_69ff6ab696b0570f10d89e70e5b5fc94);
#
#
#         marker_80ccdcbd552ef5c3085b34645477b1aa.bindPopup(popup_2d97e4b185f373c829f773022e86779a)
#         ;
#
#
#
#
#             marker_80ccdcbd552ef5c3085b34645477b1aa.bindTooltip(
#                 `&lt;div&gt;
#                      광주광역시 북구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7f4a54597e2c6a40875927743481dd0b = L.marker(
#                 [35.1329009, 126.9025733],
#                 {}
#             ).addTo(map_e1d558d7cb5d17fd3c95a5f4ba5dbb5d);
#
#
#         var popup_8a3b789c639f46e23f09e1b44dd2777c = L.popup({&quot;maxWidth&quot;: 200});

# %%
map.save('광주시_주요관공서.html')

# %%
 #Open street map에 광주광역시청과 구청을 표시
map = folium.Map(location=[35.159841, 126.851784], zoom_start=13)
folium.Marker(
    location=[35.159841, 126.851784],
    popup=folium.Popup('광주광역시 서구 내방로 111', max_width=200),
    tooltip='광주광역시청'
).add_to(map)
folium.Marker(
    location=[35.146107, 126.923315],
    popup=folium.Popup('광주광역시 동구 서남로 1', max_width=200),
    tooltip='광주 동구청'
).add_to(map)
folium.Marker(
    location=[35.152089, 126.889858],
    popup=folium.Popup('광주광역시 서구 농성동 경열로 33', max_width=200),
    tooltip='광주 서구청'
).add_to(map)
folium.Marker(
    location=[35.1741, 126.912157],
    popup=folium.Popup('광주광역시 북구 우치로 77', max_width=200),
    tooltip='광주 북구청'
).add_to(map)
folium.Marker(
    location=[35.132901, 126.902573],
    popup=folium.Popup('광주광역시 남구 봉선로 1', max_width=200),
    tooltip='광주 남구청'
).add_to(map)
folium.Marker(
    location=[35.159552, 126.793807],
    popup=folium.Popup('광주광역시 광산구 광산로29번길 15', max_width=200),
    tooltip='광주 광산구청'
).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b7d4b3330f089df6977b2e01f7c39c9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b7d4b3330f089df6977b2e01f7c39c9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_3b7d4b3330f089df6977b2e01f7c39c9 = L.map(
#                 &quot;map_3b7d4b3330f089df6977b2e01f7c39c9&quot;,
#                 {
#                     center: [35.159841, 126.851784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef7e84b4ff9a1e51d10e6bf8dda1cc30 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3b7d4b3330f089df6977b2e01f7c39c9);
#
#
#             var marker_fcb52d5777625aa5ad625609815970f0 = L.marker(
#                 [35.159841, 126.851784],
#                 {}
#             ).addTo(map_3b7d4b3330f089df6977b2e01f7c39c9);
#
#
#         var popup_bc2311558d20ac91a02b566beb395eac = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_56fc6b81f24126244d5bdca4fbf80956 = $(`&lt;div id=&quot;html_56fc6b81f24126244d5bdca4fbf80956&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 서구 내방로 111&lt;/div&gt;`)[0];
#             popup_bc2311558d20ac91a02b566beb395eac.setContent(html_56fc6b81f24126244d5bdca4fbf80956);
#
#
#         marker_fcb52d5777625aa5ad625609815970f0.bindPopup(popup_bc2311558d20ac91a02b566beb395eac)
#         ;
#
#
#
#
#             marker_fcb52d5777625aa5ad625609815970f0.bindTooltip(
#                 `&lt;div&gt;
#                      광주광역시청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6beb3e3795f0e8f0945de05aed31df22 = L.marker(
#                 [35.146107, 126.923315],
#                 {}
#             ).addTo(map_3b7d4b3330f089df6977b2e01f7c39c9);
#
#
#         var popup_d039dc227f032a8b89c1f9f185360be8 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_5ca91746ddbec175d2d65cf114d10742 = $(`&lt;div id=&quot;html_5ca91746ddbec175d2d65cf114d10742&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 동구 서남로 1&lt;/div&gt;`)[0];
#             popup_d039dc227f032a8b89c1f9f185360be8.setContent(html_5ca91746ddbec175d2d65cf114d10742);
#
#
#         marker_6beb3e3795f0e8f0945de05aed31df22.bindPopup(popup_d039dc227f032a8b89c1f9f185360be8)
#         ;
#
#
#
#
#             marker_6beb3e3795f0e8f0945de05aed31df22.bindTooltip(
#                 `&lt;div&gt;
#                      광주 동구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_51c6ea78706c275750f3bd79c2906581 = L.marker(
#                 [35.152089, 126.889858],
#                 {}
#             ).addTo(map_3b7d4b3330f089df6977b2e01f7c39c9);
#
#
#         var popup_ed5d42afcd49f6c2f840ebe6dd604c8d = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_f7d147fd556ecfacdc2a7a582e1cbbd1 = $(`&lt;div id=&quot;html_f7d147fd556ecfacdc2a7a582e1cbbd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 서구 농성동 경열로 33&lt;/div&gt;`)[0];
#             popup_ed5d42afcd49f6c2f840ebe6dd604c8d.setContent(html_f7d147fd556ecfacdc2a7a582e1cbbd1);
#
#
#         marker_51c6ea78706c275750f3bd79c2906581.bindPopup(popup_ed5d42afcd49f6c2f840ebe6dd604c8d)
#         ;
#
#
#
#
#             marker_51c6ea78706c275750f3bd79c2906581.bindTooltip(
#                 `&lt;div&gt;
#                      광주 서구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_989a78887dd4a8b97391d7cc27d03e0d = L.marker(
#                 [35.1741, 126.912157],
#                 {}
#             ).addTo(map_3b7d4b3330f089df6977b2e01f7c39c9);
#
#
#         var popup_744300421bf81ecab540c8632f2ab180 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_fc6f0d2d88d6cfe63bf8d560dd185dd0 = $(`&lt;div id=&quot;html_fc6f0d2d88d6cfe63bf8d560dd185dd0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 북구 우치로 77&lt;/div&gt;`)[0];
#             popup_744300421bf81ecab540c8632f2ab180.setContent(html_fc6f0d2d88d6cfe63bf8d560dd185dd0);
#
#
#         marker_989a78887dd4a8b97391d7cc27d03e0d.bindPopup(popup_744300421bf81ecab540c8632f2ab180)
#         ;
#
#
#
#
#             marker_989a78887dd4a8b97391d7cc27d03e0d.bindTooltip(
#                 `&lt;div&gt;
#                      광주 북구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ca9f36aad3f94addee80e71666fe4e04 = L.marker(
#                 [35.132901, 126.902573],
#                 {}
#             ).addTo(map_3b7d4b3330f089df6977b2e01f7c39c9);
#
#
#         var popup_808c642bf8a70c9c32c7db8c6cae1a10 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_

# %%
map.save('광주시_주요관공서.html')

# %%
# Stamen Toner map에 광주광역시청과 구청을 표시
from folium.features import CustomIcon, DivIcon

map = folium.Map(location=[35.159841, 126.851784], tiles="Stamen Toner", zoom_start=13)
folium.Marker(
    location=[35.159841, 126.851784],
    popup=folium.Popup('광주광역시 서구 내방로 111', max_width=200),
    tooltip='광주광역시청',
).add_to(map)
folium.Marker(
    location=[35.146107, 126.923315],
    popup=folium.Popup('광주광역시 동구 서남로 1', max_width=200),
    tooltip='광주 동구청',
    icon=DivIcon(icon_size=(100,20), icon_anchor=(0,0),
                 html='<div style="font-size: 14pt; background-color: powderblue"><bold>광주 동구청</bold></div>')
).add_to(map)
folium.Circle(
    radius=250,
    location=[35.152089, 126.889858],
    popup=folium.Popup('광주광역시 서구 농성동 경열로 33', max_width=200),
    tooltip='광주 서구청',
    color='magenta',
    fill=True
).add_to(map)
folium.CircleMarker(
    radius=20,
    location=[35.1741, 126.912157],
    popup=folium.Popup('광주광역시 북구 우치로 77', max_width=200),
    tooltip='광주 북구청',
    color="#3186aa",        # RGB, 16진수
    fill=True,
    fill_color="#3186dd"
).add_to(map)
folium.Marker(
    location=[35.132901, 126.902573],
    popup=folium.Popup('광주광역시 남구 봉선로 1', max_width=200),
    tooltip='광주 남구청',
    icon=folium.Icon('darkred', icon='star')
).add_to(map)
folium.Marker(
    location=[35.159552, 126.793807],
    popup=folium.Popup('광주광역시 광산구 광산로29번길 15', max_width=200),
    tooltip='광주 광산구청',
    icon=folium.Icon('blue', icon='plane')
).add_to(map)

title_html = '<h3 align="center">광주광역시 주요 행정기관</h3>'
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c1d480f01460f68099bca45ce33efcb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#     &lt;h3 align=&quot;center&quot;&gt;광주광역시 주요 행정기관&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c1d480f01460f68099bca45ce33efcb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6c1d480f01460f68099bca45ce33efcb = L.map(
#                 &quot;map_6c1d480f01460f68099bca45ce33efcb&quot;,
#                 {
#                     center: [35.159841, 126.851784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7767a48497e8a8a741e4eec09e80bb0b = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6c1d480f01460f68099bca45ce33efcb);
#
#
#             var marker_e2dae67b39281369c123eb4f9b28653a = L.marker(
#                 [35.159841, 126.851784],
#                 {}
#             ).addTo(map_6c1d480f01460f68099bca45ce33efcb);
#
#
#         var popup_2ed3cc0be9c4e91ee939bd44adffe1e8 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_6b0c9b41b2c335037ab6fb5c8eb0c817 = $(`&lt;div id=&quot;html_6b0c9b41b2c335037ab6fb5c8eb0c817&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 서구 내방로 111&lt;/div&gt;`)[0];
#             popup_2ed3cc0be9c4e91ee939bd44adffe1e8.setContent(html_6b0c9b41b2c335037ab6fb5c8eb0c817);
#
#
#         marker_e2dae67b39281369c123eb4f9b28653a.bindPopup(popup_2ed3cc0be9c4e91ee939bd44adffe1e8)
#         ;
#
#
#
#
#             marker_e2dae67b39281369c123eb4f9b28653a.bindTooltip(
#                 `&lt;div&gt;
#                      광주광역시청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5e6105b04dbb38b7aa2ffa81d89a7b3e = L.marker(
#                 [35.146107, 126.923315],
#                 {}
#             ).addTo(map_6c1d480f01460f68099bca45ce33efcb);
#
#
#             var div_icon_881eccc98708f685a067f08462c1ba4a = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 14pt; background-color: powderblue\&quot;\u003e\u003cbold\u003e\uad11\uc8fc \ub3d9\uad6c\uccad\u003c/bold\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [100, 20]});
#             marker_5e6105b04dbb38b7aa2ffa81d89a7b3e.setIcon(div_icon_881eccc98708f685a067f08462c1ba4a);
#
#
#         var popup_77df5bef5921105732c73dae9f105846 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_a9f156c1a4035a16a984a890c694720e = $(`&lt;div id=&quot;html_a9f156c1a4035a16a984a890c694720e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 동구 서남로 1&lt;/div&gt;`)[0];
#             popup_77df5bef5921105732c73dae9f105846.setContent(html_a9f156c1a4035a16a984a890c694720e);
#
#
#         marker_5e6105b04dbb38b7aa2ffa81d89a7b3e.bindPopup(popup_77df5bef5921105732c73dae9f105846)
#         ;
#
#
#
#
#             marker_5e6105b04dbb38b7aa2ffa81d89a7b3e.bindTooltip(
#                 `&lt;div&gt;
#                      광주 동구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_cab87c71cb7cb733e8acfa9f31c254bd = L.circle(
#                 [35.152089, 126.889858],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;magenta&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;magenta&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 250, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6c1d480f01460f68099bca45ce33efcb);
#
#
#         var popup_fd52ad7077ab4d079f67ff57a318b387 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_a2a26ca896d182df1d4f1b7486e0a733 = $(`&lt;div id=&quot;html_a2a26ca896d182df1d4f1b7486e0a733&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 서구 농성동 경열로 33&lt;/div&gt;`)[0];
#             popup_fd52ad7077ab4d079f67ff57a318b387.setContent(html_a2a26ca896d182df1d4f1b7486e0a733);
#
#
#         circle_cab87c71cb7cb733e8acfa9f31c254bd.bindPopup(popup_fd52ad7077ab4d079f67ff57a318b387)
#         ;
#
#
#
#
#             circle_cab87c71cb7cb733e8acfa9f31c254bd.bindTooltip(
#                 `&lt;div&gt;
#                      광주 서구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_7ec8bbdcf7b42dce33876eac900e96d0 = L.circ
